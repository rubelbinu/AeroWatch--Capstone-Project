# %%
import os, cv2, random, torch, pandas as pd
import numpy as np
from PIL import Image, ImageDraw

# %%
image_folder_path = './Images'  
label_folder_path = './Labels'

# %%
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        if filename.endswith(".jpg") or filename.endswith(".png"):  
            img_path = os.path.join(folder, filename)
            img = Image.open(img_path)
            images.append((filename, img))
    return images

images = load_images_from_folder(image_folder_path)

# %%
# Verify the loaded images
for name, img in images:
    print(f"Loaded image: {name} with size {img.size}")
# Out:
# Loaded image: b4a0dee3-out_2_1_114.png with size (720, 480)
# Loaded image: 1e8a186e-out_2_1_115.png with size (720, 480)
# Loaded image: 43b22044-out_2_3_224.png with size (720, 480)
# Loaded image: c81d8cf6-out_2_3_28.png with size (720, 480)
# Loaded image: 7effeb40-out_2_1_519.png with size (720, 480)
# Loaded image: 89b8ceb1-out_2_1_631.png with size (720, 480)
# Loaded image: 0b521441-out_2_2_52.png with size (720, 480)
# Loaded image: fdea3287-out_2_1_216.png with size (720, 480)
# Loaded image: e7aff56a-out_2_1_63.png with size (720, 480)
# Loaded image: 7a15af8b-out_2_2_123.png with size (720, 480)
# Loaded image: ba795fad-out_2_1_52.png with size (720, 480)
# Loaded image: 4ec07b08-out_2_2_920.png with size (720, 480)
# Loaded image: a34025ea-out_2_2_423.png with size (720, 480)
# Loaded image: bba60658-out_2_2_22.png with size (720, 480)
# Loaded image: 7a64aa6c-out_2_3_329.png with size (720, 480)
# Loaded image: 4edd2682-out_2_3_25.png with size (720, 480)
# Loaded image: ed9a35a8-out_2_1_15.png with size (720, 480)
# Loaded image: a42c0ddb-out_2_1_1013.png with size (720, 480)
# Loaded image: b4233a8a-09152008flight2tape3_436.png with size (720, 480)
# Loaded image: 4d11e0bc-out_2_2_95.png with size (720, 480)
# Loaded image: f369f6e8-out_2_2_56.png with size (720, 480)
# Loaded image: ba25bba4-out_2_1_1014.png with size (720, 480)
# Loaded image: 3e96935f-out_2_1_615.png with size (720, 480)
# Loaded image: 2a58607b-out_2_1_65.png with size (720, 480)
# Loaded image: c3e7656e-out_2_2_524.png with size (720, 480)
# Loaded image: 8c25c2cb-out_2_1_21.png with size (720, 480)
# Loaded image: d7b18391-09152008flight2tape3_428.png with size (720, 480)
# Loaded image: 358cbac0-out_2_2_16.png with size (720, 480)
# Loaded image: 91c7c70d-09152008flight2tape3_928.png with size (720, 480)
# Loaded image: 911c1f09-out_2_1_218.png with size (720, 480)
# Loaded image: ffdb491b-out_2_2_57.png with size (720, 480)
# Loaded image: 5e796fba-out_2_1_74.png with size (720, 480)
# Loaded image: 9b6983a5-out_2_1_54.png with size (720, 480)
# Loaded image: f1d5e90a-09152008flight2tape3_456.png with size (720, 480)
# Loaded image: 520307ac-out_2_1_1031.png with size (720, 480)
# Loaded image: 6f2f464b-out_2_3_221.png with size (720, 480)
# Loaded image: a8b70549-out_2_3_328.png with size (720, 480)
# Loaded image: 57269805-out_2_2_217.png with size (720, 480)
# Loaded image: 5813e342-out_2_1_1029.png with size (720, 480)
# Loaded image: 38743089-out_2_1_224.png with size (720, 480)
# Loaded image: 4103aa86-out_2_2_822.png with size (720, 480)
# Loaded image: e0245883-out_2_1_530.png with size (720, 480)
# Loaded image: bd972f8f-out_2_1_523.png with size (720, 480)
# Loaded image: 1b2daef4-out_2_3_117.png with size (720, 480)
# Loaded image: 2177e51f-out_2_1_125.png with size (720, 480)
# Loaded image: 5951c1f6-out_2_3_322.png with size (720, 480)
# Loaded image: dd955c41-09152008flight2tape3_958.png with size (720, 480)
# Loaded image: 096b623b-out_2_3_223.png with size (720, 480)
# Loaded image: af2f2d14-out_2_3_120.png with size (720, 480)
# Loaded image: d3cde675-out_2_1_727.png with size (720, 480)
# Loaded image: 4b7ca413-out_2_3_330.png with size (720, 480)
# Loaded image: 38284693-out_2_2_929.png with size (720, 480)
# Loaded image: 714028c4-out_2_2_122.png with size (720, 480)
# Loaded image: f3cfafd0-out_2_2_918.png with size (720, 480)
# Loaded image: 75121a64-out_2_1_129.png with size (720, 480)
# Loaded image: 56b35dd7-out_2_1_728.png with size (720, 480)
# Loaded image: d9ed54ff-out_2_1_73.png with size (720, 480)
# Loaded image: 6c9b2749-out_2_3_113.png with size (720, 480)
# Loaded image: bf8dddb9-out_2_3_26.png with size (720, 480)
# Loaded image: fba4fee0-out_2_3_231.png with size (720, 480)
# Loaded image: ee6b2eb0-out_2_1_14.png with size (720, 480)
# Loaded image: 71f1f0e4-09152008flight2tape3_423.png with size (720, 480)
# Loaded image: 969863e9-out_2_1_108.png with size (720, 480)
# Loaded image: ea79072a-out_2_3_22.png with size (720, 480)
# Loaded image: 69a24c77-out_2_2_18.png with size (720, 480)
# Loaded image: 11ef8c91-out_2_1_1018.png with size (720, 480)
# Loaded image: 5176b140-out_2_1_525.png with size (720, 480)
# Loaded image: 40546368-09152008flight2tape3_926.png with size (720, 480)
# Loaded image: 1074b709-out_2_1_616.png with size (720, 480)
# Loaded image: 1b7d568d-out_2_3_119.png with size (720, 480)
# Loaded image: 21a59a5a-out_2_1_721.png with size (720, 480)
# Loaded image: f801feee-out_2_2_824.png with size (720, 480)
# Loaded image: 0da35ee5-out_2_3_130.png with size (720, 480)
# Loaded image: 5b8ba660-out_2_3_24.png with size (720, 480)
# Loaded image: f46fd5e4-out_2_3_230.png with size (720, 480)
# Loaded image: bf87073a-09152008flight2tape3_45.png with size (720, 480)
# Loaded image: be9f5adb-out_2_1_1030.png with size (720, 480)
# Loaded image: 753e0b38-out_2_2_924.png with size (720, 480)
# Loaded image: 9da67154-out_2_1_64.png with size (720, 480)
# Loaded image: eadb65c8-out_2_2_215.png with size (720, 480)
# Loaded image: 8b7c2393-out_2_2_124.png with size (720, 480)
# Loaded image: 28e2bcb9-out_2_1_1020.png with size (720, 480)
# Loaded image: 26dff48a-out_2_1_126.png with size (720, 480)
# Loaded image: 164afb62-out_2_3_312.png with size (720, 480)
# Loaded image: 0849dbc6-out_2_2_86.png with size (720, 480)
# Loaded image: c76d5b31-out_2_1_26.png with size (720, 480)
# Loaded image: 640530ba-out_2_2_919.png with size (720, 480)
# Loaded image: 1b272ed3-out_2_2_817.png with size (720, 480)
# Loaded image: bfd6d315-out_2_1_726.png with size (720, 480)
# Loaded image: 386a8210-out_2_3_318.png with size (720, 480)
# Loaded image: 009cbc0a-09152008flight2tape3_431.png with size (720, 480)
# Loaded image: 0bde31bb-09152008flight2tape3_435.png with size (720, 480)
# Loaded image: 920bfe9c-out_2_1_17.png with size (720, 480)
# Loaded image: db2efefe-out_2_1_517.png with size (720, 480)
# Loaded image: e759c9c3-out_2_2_227.png with size (720, 480)
# Loaded image: e3cf98bb-out_2_2_825.png with size (720, 480)
# Loaded image: 75e5b04d-out_2_2_216.png with size (720, 480)
# Loaded image: edb9a8d1-out_2_3_21.png with size (720, 480)
# Loaded image: ebb0b513-out_2_3_15.png with size (720, 480)
# Loaded image: d3ec0a59-out_2_1_57.png with size (720, 480)
# Loaded image: d0e47507-out_2_1_71.png with size (720, 480)
# Loaded image: 244077d5-out_2_2_820.png with size (720, 480)
# Loaded image: 8b53fd3d-out_2_1_722.png with size (720, 480)
# Loaded image: 8a7fd22f-out_2_1_723.png with size (720, 480)
# Loaded image: 75922b97-out_2_1_23.png with size (720, 480)
# Loaded image: de473334-out_2_1_22.png with size (720, 480)
# Loaded image: dfa22b1b-out_2_3_111.png with size (720, 480)
# Loaded image: 7d6cf9f9-09152008flight2tape3_950.png with size (720, 480)
# Loaded image: 1daddba6-out_2_1_221.png with size (720, 480)
# Loaded image: b0a06927-out_2_2_915.png with size (720, 480)
# Loaded image: 41e9e884-out_2_1_78.png with size (720, 480)
# Loaded image: b18db9f1-out_2_1_521.png with size (720, 480)
# Loaded image: b7a5de2c-out_2_1_211.png with size (720, 480)
# Loaded image: fe8b5f42-out_2_3_326.png with size (720, 480)
# Loaded image: 55f2554f-out_2_2_930.png with size (720, 480)
# Loaded image: 8cbd997c-out_2_3_317.png with size (720, 480)
# Loaded image: 641e0441-out_2_1_19.png with size (720, 480)
# Loaded image: 8dc86be0-out_2_1_11.png with size (720, 480)
# Loaded image: 4a920590-out_2_3_17.png with size (720, 480)
# Loaded image: aaaa634a-out_2_3_320.png with size (720, 480)
# Loaded image: d811805b-out_2_1_124.png with size (720, 480)
# Loaded image: 34bc507a-out_2_3_222.png with size (720, 480)
# Loaded image: 49d4df51-09152008flight2tape3_953.png with size (720, 480)
# Loaded image: 4e292419-out_2_1_76.png with size (720, 480)
# Loaded image: dfa05bfb-out_2_3_127.png with size (720, 480)
# Loaded image: c0e2e2f7-out_2_2_831.png with size (720, 480)
# Loaded image: 44acb9ef-out_2_1_118.png with size (720, 480)
# Loaded image: 6b63f8ce-out_2_2_11.png with size (720, 480)
# Loaded image: 38fecefb-09152008flight2tape3_957.png with size (720, 480)
# Loaded image: df5883bd-out_2_2_228.png with size (720, 480)
# Loaded image: ec9fe13e-09152008flight2tape3_930.png with size (720, 480)
# Loaded image: f0c61e46-09152008flight2tape3_41.png with size (720, 480)
# Loaded image: 32bf9ec1-out_2_2_222.png with size (720, 480)
# Loaded image: 35dc14b7-out_2_3_110.png with size (720, 480)
# Loaded image: 68b3bd3a-09152008flight2tape3_440.png with size (720, 480)
# Loaded image: 5dc62ac5-out_2_2_927.png with size (720, 480)
# Loaded image: 994702f4-out_2_1_1025.png with size (720, 480)
# Loaded image: d18546ed-out_2_1_109.png with size (720, 480)
# Loaded image: 199e43bc-out_2_2_23.png with size (720, 480)
# Loaded image: 6314ffea-out_2_3_128.png with size (720, 480)
# Loaded image: a7d9cb36-out_2_3_12.png with size (720, 480)
# Loaded image: 103a24e8-out_2_2_97.png with size (720, 480)
# Loaded image: f3df1e01-out_2_1_12.png with size (720, 480)
# Loaded image: edcd47ed-out_2_1_1019.png with size (720, 480)
# Loaded image: 19611947-out_2_1_522.png with size (720, 480)
# Loaded image: f9c18331-09152008flight2tape3_944.png with size (720, 480)
# Loaded image: 30432c86-out_2_1_220.png with size (720, 480)
# Loaded image: 62a02346-out_2_2_431.png with size (720, 480)
# Loaded image: 7d447a29-out_2_1_1022.png with size (720, 480)
# Loaded image: e73dd156-09152008flight2tape3_444.png with size (720, 480)
# Loaded image: 32e454d5-out_2_2_82.png with size (720, 480)
# Loaded image: 53ba0af6-out_2_2_827.png with size (720, 480)
# Loaded image: 9e988c51-09152008flight2tape3_47.png with size (720, 480)
# Loaded image: 38471b3c-out_2_3_331.png with size (720, 480)
# Loaded image: b0eab920-out_2_2_231.png with size (720, 480)
# Loaded image: ca47c8de-09152008flight2tape3_453.png with size (720, 480)
# Loaded image: cc399ece-out_2_3_23.png with size (720, 480)
# Loaded image: 7c84e285-out_2_3_315.png with size (720, 480)
# Loaded image: dccb3310-out_2_1_128.png with size (720, 480)
# Loaded image: dffb923d-09152008flight2tape3_929.png with size (720, 480)
# Loaded image: 8b1249e3-out_2_3_18.png with size (720, 480)
# Loaded image: 1f58dcbb-out_2_2_94.png with size (720, 480)
# Loaded image: 688efcfb-out_2_1_617.png with size (720, 480)
# Loaded image: eebb5199-out_2_1_24.png with size (720, 480)
# Loaded image: 97696298-out_2_1_119.png with size (720, 480)
# Loaded image: 129af313-out_2_1_13.png with size (720, 480)
# Loaded image: f7acb1ea-out_2_1_214.png with size (720, 480)
# Loaded image: d744076c-out_2_1_210.png with size (720, 480)
# Loaded image: 7eee0017-out_2_2_126.png with size (720, 480)
# Loaded image: e76f7f20-out_2_2_14.png with size (720, 480)
# Loaded image: e8d474df-09152008flight2tape3_927.png with size (720, 480)
# Loaded image: 57813419-09152008flight2tape3_932.png with size (720, 480)
# Loaded image: f2a1f65f-out_2_2_830.png with size (720, 480)
# Loaded image: ffcfdbbf-out_2_3_118.png with size (720, 480)
# Loaded image: 276da565-out_2_2_118.png with size (720, 480)
# Loaded image: d42bbeae-out_2_2_819.png with size (720, 480)
# Loaded image: 0f083450-out_2_1_223.png with size (720, 480)
# Loaded image: bd912c5a-out_2_3_227.png with size (720, 480)
# Loaded image: 3f4c91ba-out_2_2_823.png with size (720, 480)
# Loaded image: 72c8d0db-out_2_1_27.png with size (720, 480)
# Loaded image: 296fde3d-out_2_3_16.png with size (720, 480)
# Loaded image: a2846fd8-out_2_2_828.png with size (720, 480)
# Loaded image: 4579eadd-out_2_1_122.png with size (720, 480)
# Loaded image: f13e1874-out_2_1_518.png with size (720, 480)
# Loaded image: cfc9664e-out_2_3_129.png with size (720, 480)
# Loaded image: 0be4b816-out_2_1_215.png with size (720, 480)
# Loaded image: 31ea3084-09152008flight2tape3_931.png with size (720, 480)
# Loaded image: f0ad739e-out_2_2_83.png with size (720, 480)
# Loaded image: d893db7a-out_2_1_1010.png with size (720, 480)
# Loaded image: 51192537-out_2_2_223.png with size (720, 480)
# Loaded image: 951e347b-out_2_1_53.png with size (720, 480)
# Loaded image: 1a7d8ea8-out_2_2_417.png with size (720, 480)
# Loaded image: 2284e652-09152008flight2tape3_925.png with size (720, 480)
# Loaded image: 02a1d698-out_2_3_19.png with size (720, 480)
# Loaded image: ba41fb23-out_2_1_1024.png with size (720, 480)
# Loaded image: 17819503-out_2_2_821.png with size (720, 480)
# Loaded image: f7ddfd07-out_2_1_1016.png with size (720, 480)
# Loaded image: b23d330b-out_2_2_21.png with size (720, 480)
# Loaded image: 56ef93a7-09152008flight2tape3_940.png with size (720, 480)
# Loaded image: 849024d8-out_2_3_327.png with size (720, 480)
# Loaded image: 672c8b56-out_2_3_217.png with size (720, 480)
# Loaded image: a4f4df65-out_2_3_311.png with size (720, 480)
# Loaded image: 06c8cae3-out_2_3_226.png with size (720, 480)
# Loaded image: 8dcf62f7-out_2_1_531.png with size (720, 480)
# Loaded image: abf7dbd0-out_2_2_818.png with size (720, 480)
# Loaded image: c581ed69-out_2_2_218.png with size (720, 480)
# Loaded image: 91202688-out_2_2_926.png with size (720, 480)
# Loaded image: 5aebaf21-out_2_2_219.png with size (720, 480)
# Loaded image: 01f48b27-out_2_1_511.png with size (720, 480)
# Loaded image: bcf11e9a-out_2_1_127.png with size (720, 480)
# Loaded image: d5b7af3e-09152008flight2tape3_952.png with size (720, 480)
# Loaded image: 67b4ac62-out_2_2_96.png with size (720, 480)
# Loaded image: 54bcecb6-out_2_1_104.png with size (720, 480)
# Loaded image: df82bf80-out_2_1_77.png with size (720, 480)
# Loaded image: 10c9ae20-out_2_2_55.png with size (720, 480)
# Loaded image: 95e4b8e0-out_2_1_123.png with size (720, 480)
# Loaded image: 91e4159c-out_2_1_725.png with size (720, 480)
# Loaded image: d0f3a3b3-out_2_2_923.png with size (720, 480)
# Loaded image: bdd29bff-out_2_3_211.png with size (720, 480)
# Loaded image: 7b6cccb3-out_2_1_58.png with size (720, 480)
# Loaded image: cfc46c99-out_2_1_629.png with size (720, 480)
# Loaded image: a3fa320b-out_2_2_917.png with size (720, 480)
# Loaded image: 1e934c48-out_2_2_225.png with size (720, 480)
# Loaded image: c86083e4-out_2_2_130.png with size (720, 480)
# Loaded image: ee6b671e-out_2_2_214.png with size (720, 480)
# Loaded image: 3d477740-out_2_3_112.png with size (720, 480)
# Loaded image: 2ca1d2f0-out_2_2_931.png with size (720, 480)
# Loaded image: a5257927-out_2_2_51.png with size (720, 480)
# Loaded image: 015e2a80-out_2_2_92.png with size (720, 480)
# Loaded image: e2a973b4-out_2_3_13.png with size (720, 480)
# Loaded image: e264db33-out_2_1_213.png with size (720, 480)
# Loaded image: 6e3e2517-out_2_2_98.png with size (720, 480)
# Loaded image: b69a779d-out_2_1_103.png with size (720, 480)
# Loaded image: 330e2f5e-out_2_1_101.png with size (720, 480)
# Loaded image: 844ce92b-out_2_1_1023.png with size (720, 480)
# Loaded image: 550de034-out_2_1_1017.png with size (720, 480)
# Loaded image: 0fa9771c-out_2_1_102.png with size (720, 480)
# Loaded image: 744b8e03-out_2_2_916.png with size (720, 480)
# Loaded image: 31eb096c-09152008flight2tape3_936.png with size (720, 480)
# Loaded image: 177d95ef-out_2_2_91.png with size (720, 480)
# Loaded image: 9e11031d-out_2_2_921.png with size (720, 480)
# Loaded image: 1fbf17e7-out_2_1_625.png with size (720, 480)
# Loaded image: 8866b2fb-out_2_1_1028.png with size (720, 480)
# Loaded image: 272019b6-out_2_1_29.png with size (720, 480)
# Loaded image: f3ef11cb-out_2_1_219.png with size (720, 480)
# Loaded image: 484f9342-out_2_2_829.png with size (720, 480)
# Loaded image: 06b65cae-09152008flight2tape3_951.png with size (720, 480)
# Loaded image: 5a4941c8-out_2_3_124.png with size (720, 480)
# Loaded image: c20bd872-out_2_1_516.png with size (720, 480)
# Loaded image: 6998b308-out_2_1_1021.png with size (720, 480)
# Loaded image: 8f75b600-out_2_2_17.png with size (720, 480)
# Loaded image: 78f9ea9b-out_2_2_15.png with size (720, 480)
# Loaded image: b62f1366-out_2_2_25.png with size (720, 480)
# Loaded image: 18840f58-out_2_2_925.png with size (720, 480)
# Loaded image: 02509f21-out_2_2_913.png with size (720, 480)
# Loaded image: 7bad49c1-out_2_1_1015.png with size (720, 480)
# Loaded image: 4d90f5c4-09152008flight2tape3_457.png with size (720, 480)
# Loaded image: 94aca563-out_2_1_130.png with size (720, 480)
# Loaded image: 5bed90c5-out_2_1_113.png with size (720, 480)
# Loaded image: 61bb7590-out_2_3_27.png with size (720, 480)
# Loaded image: 31b1c125-out_2_2_914.png with size (720, 480)
# Loaded image: 13d3bf13-out_2_2_226.png with size (720, 480)
# Loaded image: 069e4b52-out_2_3_126.png with size (720, 480)
# Loaded image: b8f096b6-out_2_2_826.png with size (720, 480)
# Loaded image: 3642f6d6-out_2_3_215.png with size (720, 480)
# Loaded image: bf4a57de-out_2_2_93.png with size (720, 480)
# Loaded image: bf222143-out_2_1_110.png with size (720, 480)
# Loaded image: 46ba8dab-out_2_3_29.png with size (720, 480)
# Loaded image: 5389a07b-out_2_2_224.png with size (720, 480)
# Loaded image: cc634e74-out_2_2_125.png with size (720, 480)

# %%
# Load labels from text file
# label_file_path = os.path.join(label_folder_path)

label_files = os.listdir(label_folder_path)

labels = []
for file in label_files:
    with open(f"./{label_folder_path}/{file}", "r") as f:
        for line in f.read().split("\n")[:-1]:
            item = [file.replace(".txt", ".png")]
            item.extend(line.split(" "))
            labels.append(item)

# %%
df = pd.DataFrame(labels, columns=["file", "class", "x_center", "y_center", "width", "height"])
df
# Out:
#                                        file class             x_center  \
# 0                  f46fd5e4-out_2_3_230.png     0  0.06639748766262897
# 1                  f46fd5e4-out_2_3_230.png     0  0.10094212651413191
# 2                  f46fd5e4-out_2_3_230.png     0    0.063257065948856
# 3                  f46fd5e4-out_2_3_230.png     0  0.07133243606998654
# 4                  f46fd5e4-out_2_3_230.png     0   0.3965903992821893
# ...                                     ...   ...                  ...
# 1171                b23d330b-out_2_2_21.png     0  0.32211754149842975
# 1172  56ef93a7-09152008flight2tape3_940.png     0   0.5912965455361149
# 1173  56ef93a7-09152008flight2tape3_940.png     0   0.5800807537012114
# 1174  56ef93a7-09152008flight2tape3_940.png     0   0.8456707043517272
# 1175  56ef93a7-09152008flight2tape3_940.png     0   0.8995065051592642
#
#                   y_center                width                height
# 0     0.038358008075370126  0.08434275459847465    0.0740242261103634
# 1      0.07267833109017496  0.11215791834903543   0.08344549125168235
# 2       0.2913862718707941  0.08524001794526694    0.0847913862718708
# 3       0.6386271870794079  0.07985643786451323   0.12516823687752357
# 4      0.40376850605652764   0.0897263346792284   0.07537012113055191
# ...                    ...                  ...                   ...
# 1171    0.8714670255720054  0.10767160161507398   0.12247644683714669
# 1172    0.9286675639300134  0.11843876177658139  0.061911170928667617
# 1173    0.9643337819650069  0.11215791834903541  0.055181695827725294
# 1174    0.8855989232839838  0.07088380439659034   0.08075370121130547
# 1175    0.8882907133243607  0.08165096455809788   0.10497981157469724
#
# [1176 rows x 6 columns]

# %%
df["class"].unique()
# Out:
# array(['0'], dtype=object)

# %%
# Function to draw bounding boxes on images
def draw_bounding_boxes(image, labels):
    draw = ImageDraw.Draw(image)
    img_width, img_height = image.size
    for _, row in labels.iterrows():
        x_center = float(row['x_center']) * img_width
        y_center = float(row['y_center']) * img_height
        width = float(row['width']) * img_width
        height = float(row['height']) * img_height
        x1 = x_center - width / 2
        y1 = y_center - height / 2
        x2 = x_center + width / 2
        y2 = y_center + height / 2
        draw.rectangle([x1, y1, x2, y2], outline="red", width=2)
    return image

# %%
def pick_random_image(folder):
    image_files = [file for file in os.listdir(folder) if file.endswith(('.jpg', '.png'))]
    random_image = random.choice(image_files)
    return random_image

# Pick a random image
random_image_file = pick_random_image(image_folder_path)
print(f"Randomly selected image: {random_image_file}")
# Out:
# Randomly selected image: cfc9664e-out_2_3_129.png

# %%
# Select an image to display
image_to_display = random_image_file
image_labels = df[df['file'] == image_to_display]
image_path = os.path.join(image_folder_path, image_to_display)

image = Image.open(image_path)
image_with_boxes = draw_bounding_boxes(image, image_labels)
image_with_boxes.show()

# %%
# Normalize the bounding box coordinates
df[['x_center', 'y_center', 'width', 'height']] = df[['x_center', 'y_center', 'width', 'height']].astype(float)

# %%
# Resize images to a consistent size and preprocess the labels
image_size = (224, 224)
preprocessed_images = []
preprocessed_labels = []

output_image_folder = './PreprocessedImages'
os.makedirs(output_image_folder, exist_ok=True)

# %%
for name, img in images:
    # Resize image
    img_resized = img.resize(image_size)
    img_array = np.array(img_resized)
    
    # Save the resized image
    img_resized.save(os.path.join(output_image_folder, name))
    
    # Get corresponding labels
    img_labels = df[df['file'] == name]
    
    for _, row in img_labels.iterrows():
        x_center = row['x_center'] * image_size[0]
        y_center = row['y_center'] * image_size[1]
        width = row['width'] * image_size[0]
        height = row['height'] * image_size[1]
        
        # Normalize bounding box coordinates relative to the resized image dimensions
        norm_x_center = x_center / image_size[0]
        norm_y_center = y_center / image_size[1]
        norm_width = width / image_size[0]
        norm_height = height / image_size[1]
        
        preprocessed_labels.append([name, row['class'], norm_x_center, norm_y_center, norm_width, norm_height])

# %%
# Convert labels to DataFrame
preprocessed_labels_df = pd.DataFrame(preprocessed_labels, columns=["file", "class", "x_center", "y_center", "width", "height"])

# %%
# Save the preprocessed labels to a CSV file
preprocessed_labels_df.to_csv('preprocessed_labels.csv', index=False)

# %%
# Display sample preprocessed image with bounding boxes
def draw_bounding_boxes(image_array, labels):
    img = Image.fromarray(image_array)
    draw = ImageDraw.Draw(img)
    img_width, img_height = img.size
    for _, row in labels.iterrows():
        x_center = float(row['x_center']) * img_width
        y_center = float(row['y_center']) * img_height
        width = float(row['width']) * img_width
        height = float(row['height']) * img_height
        x1 = x_center - width / 2
        y1 = y_center - height / 2
        x2 = x_center + width / 2
        y2 = y_center + height / 2
        draw.rectangle([x1, y1, x2, y2], outline="red", width=2)
    return img

# %%
# Example of displaying a preprocessed image with bounding boxes
example_image_name = random_image_file
example_image_path = os.path.join(output_image_folder, example_image_name)
example_image_array = np.array(Image.open(example_image_path))
example_labels = preprocessed_labels_df[preprocessed_labels_df['file'] == example_image_name]
image_with_boxes = draw_bounding_boxes(example_image_array, example_labels)
image_with_boxes.show()
